# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df=application_df.drop(columns=["EIN","NAME"],axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
vc_app_type=application_df["APPLICATION_TYPE"].value_counts()
vc_app_type
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_app_type=500
application_types_to_replace=vc_app_type[vc_app_type < cutoff_app_type].index.to_list()
print(application_types_to_replace)
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
vc_class=application_df["CLASSIFICATION"].value_counts()
vc_class
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
vc_class2=vc_class[vc_class>1]
vc_class2
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_class=1000
classifications_to_replace = vc_class[vc_class < cutoff_class].index.to_list()
print(classifications_to_replace)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# ['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100', 'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278', 'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600', 'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256', 'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820', 'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570', 'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561', 'C4500', 'C2150']
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
#check the data types of the column.
application_df.dtypes
# Out:
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
#Identify  the categorical columns
categorical_columns = application_df.select_dtypes(include=["object"]).columns
categorical_columns
# Out:
# Index(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'],
#       dtype='object')

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(application_df,columns=categorical_columns)
dummies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
data = dummies_df.drop(columns=["IS_SUCCESSFUL"])
target= dummies_df["IS_SUCCESSFUL"]
print(target.name)
print(data.columns)
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(data,target,test_size=0.2,random_state=42)
# Out:
# IS_SUCCESSFUL
# Index(['STATUS', 'ASK_AMT', 'APPLICATION_TYPE_Other', 'APPLICATION_TYPE_T10',
#        'APPLICATION_TYPE_T19', 'APPLICATION_TYPE_T3', 'APPLICATION_TYPE_T4',
#        'APPLICATION_TYPE_T5', 'APPLICATION_TYPE_T6', 'APPLICATION_TYPE_T7',
#        'APPLICATION_TYPE_T8', 'AFFILIATION_CompanySponsored',
#        'AFFILIATION_Family/Parent', 'AFFILIATION_Independent',
#        'AFFILIATION_National', 'AFFILIATION_Other', 'AFFILIATION_Regional',
#        'CLASSIFICATION_C1000', 'CLASSIFICATION_C1200', 'CLASSIFICATION_C2000',
#        'CLASSIFICATION_C2100', 'CLASSIFICATION_C3000', 'CLASSIFICATION_Other',
#        'USE_CASE_CommunityServ', 'USE_CASE_Heathcare', 'USE_CASE_Other',
#        'USE_CASE_Preservation', 'USE_CASE_ProductDev',
#        'ORGANIZATION_Association', 'ORGANIZATION_Co-operative',
#        'ORGANIZATION_Corporation', 'ORGANIZATION_Trust', 'INCOME_AMT_0',
#        'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999',
#        'INCOME_AMT_100000-499999', 'INCOME_AMT_10M-50M', 'INCOME_AMT_1M-5M',
#        'INCOME_AMT_25000-99999', 'INCOME_AMT_50M+', 'INCOME_AMT_5M-10M',
#        'SPECIAL_CONSIDERATIONS_N', 'SPECIAL_CONSIDERATIONS_Y'],
#       dtype='object')

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=X_train.shape[1]))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
# Train the model
nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 858/858 [==============================] - 9s 6ms/step - loss: 0.5695 - accuracy: 0.7215
# Epoch 2/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5551 - accuracy: 0.7293
# Epoch 3/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5508 - accuracy: 0.7303
# Epoch 4/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5492 - accuracy: 0.7306
# Epoch 5/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5485 - accuracy: 0.7314
# Epoch 6/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5476 - accuracy: 0.7315
# Epoch 7/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5473 - accuracy: 0.7318
# Epoch 8/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5460 - accuracy: 0.7336
# Epoch 9/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5460 - accuracy: 0.7324
# Epoch 10/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5453 - accuracy: 0.7326
# Epoch 11/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5440 - accuracy: 0.7326
# Epoch 12/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5444 - accuracy: 0.7342
# Epoch 13/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5434 - accuracy: 0.7347
# Epoch 14/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5436 - accuracy: 0.7352
# Epoch 15/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5427 - accuracy: 0.7339
# Epoch 16/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5427 - accuracy: 0.7355
# Epoch 17/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5424 - accuracy: 0.7348
# Epoch 18/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5422 - accuracy: 0.7361
# Epoch 19/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5420 - accuracy: 0.7357
# Epoch 20/100
# 858/858 [==============================] - 7s 8ms/step - loss: 0.5417 - accuracy: 0.7356
# Epoch 21/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5415 - accuracy: 0.7348
# Epoch 22/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5416 - accuracy: 0.7348
# Epoch 23/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5409 - accuracy: 0.7358
# Epoch 24/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5410 - accuracy: 0.7357
# Epoch 25/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5403 - accuracy: 0.7370
# Epoch 26/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5405 - accuracy: 0.7373
# Epoch 27/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5404 - accuracy: 0.7367
# Epoch 28/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5401 - accuracy: 0.7361
# Epoch 29/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5399 - accuracy: 0.7371
# Epoch 30/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5398 - accuracy: 0.7369
# Epoch 31/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5397 - accuracy: 0.7367
# Epoch 32/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5395 - accuracy: 0.7377
# Epoch 33/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5391 - accuracy: 0.7370
# Epoch 34/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5394 - accuracy: 0.7371
# Epoch 35/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5392 - accuracy: 0.7376
# Epoch 36/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5388 - accuracy: 0.7377
# Epoch 37/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5390 - accuracy: 0.7372
# Epoch 38/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5384 - accuracy: 0.7369
# Epoch 39/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5384 - accuracy: 0.7371
# Epoch 40/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5382 - accuracy: 0.7363
# Epoch 41/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5382 - accuracy: 0.7368
# Epoch 42/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5381 - accuracy: 0.7382
# Epoch 43/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5383 - accuracy: 0.7384
# Epoch 44/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5380 - accuracy: 0.7376
# Epoch 45/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5378 - accuracy: 0.7384
# Epoch 46/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5377 - accuracy: 0.7376
# Epoch 47/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5374 - accuracy: 0.7373
# Epoch 48/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5376 - accuracy: 0.7376
# Epoch 49/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5376 - accuracy: 0.7377
# Epoch 50/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5373 - accuracy: 0.7389
# Epoch 51/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5375 - accuracy: 0.7374
# Epoch 52/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5372 - accuracy: 0.7392
# Epoch 53/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5366 - accuracy: 0.7379
# Epoch 54/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5368 - accuracy: 0.7385
# Epoch 55/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5366 - accuracy: 0.7384
# Epoch 56/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5367 - accuracy: 0.7392
# Epoch 57/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5362 - accuracy: 0.7397
# Epoch 58/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5365 - accuracy: 0.7379
# Epoch 59/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5366 - accuracy: 0.7385
# Epoch 60/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5361 - accuracy: 0.7378
# Epoch 61/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5363 - accuracy: 0.7388
# Epoch 62/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5361 - accuracy: 0.7391
# Epoch 63/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5362 - accuracy: 0.7391
# Epoch 64/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5359 - accuracy: 0.7396
# Epoch 65/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5360 - accuracy: 0.7391
# Epoch 66/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5359 - accuracy: 0.7390
# Epoch 67/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5357 - accuracy: 0.7403
# Epoch 68/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5357 - accuracy: 0.7393
# Epoch 69/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5356 - accuracy: 0.7391
# Epoch 70/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5356 - accuracy: 0.7403
# Epoch 71/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5354 - accuracy: 0.7395
# Epoch 72/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5355 - accuracy: 0.7389
# Epoch 73/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5357 - accuracy: 0.7389
# Epoch 74/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5353 - accuracy: 0.7399
# Epoch 75/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5347 - accuracy: 0.7393
# Epoch 76/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5356 - accuracy: 0.7396
# Epoch 77/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5348 - accuracy: 0.7399
# Epoch 78/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5350 - accuracy: 0.7393
# Epoch 79/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5351 - accuracy: 0.7396
# Epoch 80/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5352 - accuracy: 0.7395
# Epoch 81/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5345 - accuracy: 0.7387
# Epoch 82/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5344 - accuracy: 0.7396
# Epoch 83/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5351 - accuracy: 0.7403
# Epoch 84/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5349 - accuracy: 0.7393
# Epoch 85/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5345 - accuracy: 0.7392
# Epoch 86/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5346 - accuracy: 0.7385
# Epoch 87/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5347 - accuracy: 0.7397
# Epoch 88/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5345 - accuracy: 0.7399
# Epoch 89/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5344 - accuracy: 0.7396
# Epoch 90/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5343 - accuracy: 0.7403
# Epoch 91/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5343 - accuracy: 0.7397
# Epoch 92/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5341 - accuracy: 0.7404
# Epoch 93/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5344 - accuracy: 0.7397
# Epoch 94/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5344 - accuracy: 0.7399
# Epoch 95/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5342 - accuracy: 0.7402
# Epoch 96/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5340 - accuracy: 0.7399
# Epoch 97/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5343 - accuracy: 0.7401
# Epoch 98/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5341 - accuracy: 0.7407
# Epoch 99/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5341 - accuracy: 0.7400
# Epoch 100/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5340 - accuracy: 0.7403

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 1s - loss: 0.5650 - accuracy: 0.7277 - 1s/epoch - 5ms/step
# Loss: 0.564972996711731, Accuracy: 0.7276967763900757

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoup_Charity.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
